# %%
from tweepy import OAuth2BearerHandler, API
from json import load
from pandas import DataFrame
from re import sub

# %%
try:
  env = load(open('env.json'))
except:
  env = {}

# %%
auth = OAuth2BearerHandler(env.get("bearer_token"))
api = API(auth)

# %%
def clean_tweet(tweet):
  regex = r'(^RT)|@\w+|[^0-9A-Za-z \t]|\w+:\/\/\S+'
  return ' '.join(sub(regex, ' ', str(tweet)).split()).lower()

# %%
def get_tweets(topic, count):
  topic = f'{topic} -filter:retweets'
  df = DataFrame(columns=['date', 'user', 'is_verified', 'tweet', 'likes', 'retweets', 'user_location'])
  for i, tweet in enumerate(api.search_tweets(topic, lang='en', count=count, tweet_mode='extended')):
    df.loc[i, 'date'] = tweet.created_at
    df.loc[i, 'user'] = tweet.user.name
    df.loc[i, 'is_verified'] = tweet.user.verified
    df.loc[i, 'tweet'] = tweet.full_text
    df.loc[i, 'cleaned_tweet'] = clean_tweet(tweet.full_text)
    df.loc[i, 'likes'] = tweet.favorite_count
    df.loc[i, 'retweets'] = tweet.retweet_count
    df.loc[i, 'user_location'] = tweet.user.location
  return df

# %%
result = get_tweets('Mumbai', 10)

# %%
result.head()
# Out:
#                         date  \
# 0  2022-04-12 12:18:40+00:00
# 1  2022-04-12 12:18:38+00:00
# 2  2022-04-12 12:18:34+00:00
# 3  2022-04-12 12:18:25+00:00
# 4  2022-04-12 12:18:25+00:00
#
#                                                 user is_verified  \
# 0                                       Mehra Media™       False
# 1                                      Behnaaz Patel       False
# 2                                   Blessen Varghese       False
# 3  Ganesh Kamat_M.S.(USA)50yExp.Bldg.Structural A...       False
# 4                            𝐑𝐄𝐁𝐄𝐋★𝐁𝐨𝐲𝐜𝐨𝐭𝐭 𝐁𝐨𝐥𝐥𝐲𝐰𝐨𝐨𝐝       False
#
#                                                tweet likes retweets  \
# 0  Business Development (Sales) Internship in Mum...     0        0
# 1  @ola_supports Well this new I guess u have blo...     0        0
# 2  Or real time traffic in any Mumbai road. https...     0        0
# 3  @tourismgoi @kishanreddybjp @KishanReddyOfc @s...     0        0
# 4  Why were Bihar Police officials treated like c...     0        0
#
#    user_location                                      cleaned_tweet
# 0        Patiala  business development sales internship in mumba...
# 1  Mumbai, India  well this new i guess u have blocked my mobile...
# 2         Mumbai            or real time traffic in any mumbai road
# 3         Mumbai  igatpuri garden mumbai 2hr lt shirdi ganaka mo...
# 4              🌐  why were bihar police officials treated like c...

# %%
result.tail()
# Out:
#                         date                     user is_verified  \
# 5  2022-04-12 12:18:17+00:00             Atharv Patil       False
# 6  2022-04-12 12:18:16+00:00  𝐑𝐄𝐁𝐄𝐋★𝐁𝐨𝐲𝐜𝐨𝐭𝐭 𝐁𝐨𝐥𝐥𝐲𝐰𝐨𝐨𝐝       False
# 7  2022-04-12 12:17:41+00:00             Tanvvii Jain       False
# 8  2022-04-12 12:17:26+00:00                  Neeraj✨       False
# 9  2022-04-12 12:17:25+00:00       Navi Mumbai Police        True
#
#                                                tweet likes retweets  \
# 5  @prattweets10 @sometimes_me_ Nagpur has close ...     0        0
# 6  Why did Mumbai police never file an FIR for Su...     0        0
# 7  @ragiing_bull I might sound wrong but i have s...     0        0
# 8  Mumbai Indians is going to win their next matc...     1        1
# 9  @pj777says Thank you for contacting Navi Mumba...     0        0
#
#               user_location                                      cleaned_tweet
# 5               Pune, India  nagpur has close proximity to chhatisgarh and ...
# 6                         🌐  why did mumbai police never file an fir for su...
# 7          New Delhi, India  i might sound wrong but i have seen mumbai peo...
# 8                      600?  mumbai indians is going to win their next matc...
# 9  Navi Mumbai, Maharashtra  thank you for contacting navi mumbai police we...
